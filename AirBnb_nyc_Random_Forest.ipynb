# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("AB_NYC_2019.csv")

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
df_copy = df

# %%
from scipy import stats
import numpy as np
df=df[(np.abs(stats.zscore(df['minimum_nights'])) < 3)]

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.856800e+04  4.856800e+04  48568.000000  48568.000000  48568.000000
# mean   1.903317e+07  6.773799e+07     40.728894    -73.952083    151.702438
# std    1.097649e+07  7.865684e+07      0.054534      0.046215    227.631790
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.478906e+06  7.853251e+06     40.690008    -73.983002     69.000000
# 50%    1.970009e+07  3.093347e+07     40.723005    -73.955650    106.000000
# 75%    2.915282e+07  1.074344e+08     40.763120    -73.936160    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48568.000000       48568.000000       38678.000000
# mean         5.894766          23.362008           1.377145
# std          8.915712          44.614591           1.682314
# ...

# %%
df=df[(np.abs(stats.zscore(df['calculated_host_listings_count'])) < 3)]

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.789700e+04  4.789700e+04  47897.000000  47897.000000  47897.000000
# mean   1.889337e+07  6.660835e+07     40.728817    -73.951477    150.020836
# std    1.094889e+07  7.812892e+07      0.054831      0.046216    228.444246
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.403937e+06  7.670501e+06     40.689660    -73.982350     69.000000
# 50%    1.953370e+07  3.022427e+07     40.722900    -73.955180    105.000000
# 75%    2.886977e+07  1.051629e+08     40.763320    -73.935590    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    47897.000000       47897.000000       38400.000000
# mean         5.670439          23.660584           1.376502
# std          8.645616          44.852206           1.685664
# ...

# %%
df=df[(np.abs(stats.zscore(df['minimum_nights'])) < 3)]

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.767900e+04  4.767900e+04  47679.000000  47679.000000  47679.000000
# mean   1.890005e+07  6.669771e+07     40.728818    -73.951431    149.850941
# std    1.094555e+07  7.815868e+07      0.054844      0.046249    227.218321
# min    2.539000e+03  2.571000e+03     40.499790    -74.244420      0.000000
# 25%    9.408304e+06  7.706697e+06     40.689660    -73.982330     69.000000
# 50%    1.954438e+07  3.032062e+07     40.722880    -73.955140    105.000000
# 75%    2.888577e+07  1.053526e+08     40.763320    -73.935515    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    47679.000000       47679.000000       38265.000000
# mean         5.458210          23.721135           1.379842
# std          8.047364          44.915305           1.687341
# ...

# %%
df=df[(np.abs(stats.zscore(df['availability_365'])) < 3)]

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.767900e+04  4.767900e+04  47679.000000  47679.000000  47679.000000
# mean   1.890005e+07  6.669771e+07     40.728818    -73.951431    149.850941
# std    1.094555e+07  7.815868e+07      0.054844      0.046249    227.218321
# min    2.539000e+03  2.571000e+03     40.499790    -74.244420      0.000000
# 25%    9.408304e+06  7.706697e+06     40.689660    -73.982330     69.000000
# 50%    1.954438e+07  3.032062e+07     40.722880    -73.955140    105.000000
# 75%    2.888577e+07  1.053526e+08     40.763320    -73.935515    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    47679.000000       47679.000000       38265.000000
# mean         5.458210          23.721135           1.379842
# std          8.047364          44.915305           1.687341
# ...

# %%
df=df[(np.abs(stats.zscore(df['price'])) < 3)]

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.isnull().sum()
# Out:
# id                                   0
# name                                15
# host_id                              0
# host_name                           21
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       9233
# reviews_per_month                 9233
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# id                                 0.000000
# name                               0.031718
# host_id                            0.000000
# host_name                          0.044405
# neighbourhood_group                0.000000
# neighbourhood                      0.000000
# latitude                           0.000000
# longitude                          0.000000
# room_type                          0.000000
# price                              0.000000
# minimum_nights                     0.000000
# number_of_reviews                  0.000000
# last_review                       19.523387
# reviews_per_month                 19.523387
# calculated_host_listings_count     0.000000
# availability_365                   0.000000
# dtype: float64

# %%
df['reviews_per_month']
# Out:
# 0        0.21
# 1        0.38
# 2         NaN
# 3        4.64
# 4        0.10
#          ...
# 48890     NaN
# 48891     NaN
# 48892     NaN
# 48893     NaN
# 48894     NaN
# Name: reviews_per_month, Length: 47292, dtype: float64

# %%
df.drop(['name','host_id','host_name','last_review','reviews_per_month'],axis=1,inplace=True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# name, host_id and host_name are dropped as they not important for model prection.
# 'last_review' and 'reviews_per_month' has been dropped as there are nearly 20% missing data for these two features.

# %%
df.dtypes
# Out:
# id                                  int64
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# id                                0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
df_num = df.select_dtypes(['int64','float64'])

# %%
for col in list(df_num.columns): 
    sns.distplot(df_num[col])
    plt.show()

# %%
df['log_price']=np.log(df['price']+1)
# Out:
# <ipython-input-28-81a2ac61f752>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['log_price']=np.log(df['price']+1)

# %%
sns.distplot(df['log_price'])

# %%
df['log_minimum_nights']=np.log(df['minimum_nights']+1)
# Out:
# <ipython-input-30-12f3287dbfa1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['log_minimum_nights']=np.log(df['minimum_nights']+1)

# %%
sns.distplot(df['log_minimum_nights'])

# %%
df['log_number_of_reviews']=np.log(df['number_of_reviews']+1)
# Out:
# <ipython-input-32-feefb0444967>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['log_number_of_reviews']=np.log(df['number_of_reviews']+1)

# %%
sns.distplot(df['log_number_of_reviews'])

# %%
df['log_calculated_host_listings_count']=np.log(df['calculated_host_listings_count'])
# Out:
# <ipython-input-34-0c94f1a0f730>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['log_calculated_host_listings_count']=np.log(df['calculated_host_listings_count'])

# %%
sns.distplot(df['log_calculated_host_listings_count'])

# %% [markdown]
# Log tansformations for 'calculated_host_listing_count', 'number_of_reviews', 'minimum_nights' and the 'price' variable as they are long tailed.

# %%
df_cat=df.select_dtypes('object')

# %%
df.columns
# Out:
# Index(['id', 'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude',
#        'room_type', 'price', 'minimum_nights', 'number_of_reviews',
#        'calculated_host_listings_count', 'availability_365', 'log_price',
#        'log_minimum_nights', 'log_number_of_reviews',
#        'log_calculated_host_listings_count'],
#       dtype='object')

# %%
df_cp2=df

# %%
df.drop(['price','minimum_nights','number_of_reviews','calculated_host_listings_count'],axis=1,inplace=True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df
# Out:
#              id neighbourhood_group       neighbourhood  latitude  longitude  \
# 0          2539            Brooklyn          Kensington  40.64749  -73.97237
# 1          2595           Manhattan             Midtown  40.75362  -73.98377
# 2          3647           Manhattan              Harlem  40.80902  -73.94190
# 3          3831            Brooklyn        Clinton Hill  40.68514  -73.95976
# 4          5022           Manhattan         East Harlem  40.79851  -73.94399
# ...         ...                 ...                 ...       ...        ...
# 48890  36484665            Brooklyn  Bedford-Stuyvesant  40.67853  -73.94995
# 48891  36485057            Brooklyn            Bushwick  40.70184  -73.93317
# 48892  36485431           Manhattan              Harlem  40.81475  -73.94867
# 48893  36485609           Manhattan      Hell's Kitchen  40.75751  -73.99112
# 48894  36487245           Manhattan      Hell's Kitchen  40.76404  -73.98933
#
# ...

# %%
df.dtypes
# Out:
# id                                      int64
# neighbourhood_group                    object
# neighbourhood                          object
# latitude                              float64
# longitude                             float64
# room_type                              object
# availability_365                        int64
# log_price                             float64
# log_minimum_nights                    float64
# log_number_of_reviews                 float64
# log_calculated_host_listings_count    float64
# dtype: object

# %%
df.drop('id',axis=1,inplace=True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.dtypes
# Out:
# neighbourhood_group                    object
# neighbourhood                          object
# latitude                              float64
# longitude                             float64
# room_type                              object
# availability_365                        int64
# log_price                             float64
# log_minimum_nights                    float64
# log_number_of_reviews                 float64
# log_calculated_host_listings_count    float64
# dtype: object

# %%
df_cat=df.select_dtypes('object')

# %%
df_cat.columns
# Out:
# Index(['neighbourhood_group', 'neighbourhood', 'room_type'], dtype='object')

# %%
df['neighbourhood'].unique()
# Out:
# array(['Kensington', 'Midtown', 'Harlem', 'Clinton Hill', 'East Harlem',
#        'Murray Hill', "Hell's Kitchen", 'Upper West Side', 'Chinatown',
#        'South Slope', 'Williamsburg', 'Fort Greene', 'Chelsea',
#        'Crown Heights', 'Park Slope', 'Bedford-Stuyvesant',
#        'Windsor Terrace', 'Inwood', 'East Village', 'Greenpoint',
#        'Bushwick', 'Flatbush', 'Lower East Side',
#        'Prospect-Lefferts Gardens', 'Long Island City', 'Kips Bay',
#        'SoHo', 'Upper East Side', 'Prospect Heights',
#        'Washington Heights', 'Woodside', 'Brooklyn Heights',
#        'Carroll Gardens', 'West Village', 'Gowanus', 'Flatlands',
#        'Cobble Hill', 'Flushing', 'Boerum Hill', 'Sunnyside', 'DUMBO',
#        'St. George', 'Highbridge', 'Financial District', 'Ridgewood',
#        'Morningside Heights', 'Jamaica', 'Middle Village', 'NoHo',
#        'Ditmars Steinway', 'Flatiron District', 'Roosevelt Island',
# ...

# %%
df_num= df.select_dtypes(['int64','float64'])

# %%
df_cat= df.select_dtypes(['object'])

# %%
cat_cols=list(df_cat.columns)

# %%
y = df['log_price']

# %%
X = df.drop('log_price', axis=1)

# %%
X
# Out:
#       neighbourhood_group       neighbourhood  latitude  longitude  \
# 0                Brooklyn          Kensington  40.64749  -73.97237
# 1               Manhattan             Midtown  40.75362  -73.98377
# 2               Manhattan              Harlem  40.80902  -73.94190
# 3                Brooklyn        Clinton Hill  40.68514  -73.95976
# 4               Manhattan         East Harlem  40.79851  -73.94399
# ...                   ...                 ...       ...        ...
# 48890            Brooklyn  Bedford-Stuyvesant  40.67853  -73.94995
# 48891            Brooklyn            Bushwick  40.70184  -73.93317
# 48892           Manhattan              Harlem  40.81475  -73.94867
# 48893           Manhattan      Hell's Kitchen  40.75751  -73.99112
# 48894           Manhattan      Hell's Kitchen  40.76404  -73.98933
#
#              room_type  availability_365  log_minimum_nights  \
# 0         Private room               365            0.693147
# ...

# %%
X_copy = X.copy()

# %%
X = pd.get_dummies(X, drop_first=True, columns=cat_cols)

# %%
X
# Out:
#        latitude  longitude  availability_365  log_minimum_nights  \
# 0      40.64749  -73.97237               365            0.693147
# 1      40.75362  -73.98377               355            0.693147
# 2      40.80902  -73.94190               365            1.386294
# 3      40.68514  -73.95976               194            0.693147
# 4      40.79851  -73.94399                 0            2.397895
# ...         ...        ...               ...                 ...
# 48890  40.67853  -73.94995                 9            1.098612
# 48891  40.70184  -73.93317                36            1.609438
# 48892  40.81475  -73.94867                27            2.397895
# 48893  40.75751  -73.99112                 2            0.693147
# 48894  40.76404  -73.98933                23            2.079442
#
#        log_number_of_reviews  log_calculated_host_listings_count  \
# 0                   2.302585                            1.791759
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
X_std = sc.fit_transform(X)

# %%
X_std
# Out:
# array([[-1.47981403, -0.45733139,  1.97081709, ..., -0.07051657,
#          1.0690268 , -0.15737726],
#        [ 0.45243052, -0.70386248,  1.89382486, ..., -0.07051657,
#         -0.93543024, -0.15737726],
#        [ 1.46106472,  0.20159864,  1.97081709, ..., -0.07051657,
#          1.0690268 , -0.15737726],
#        ...,
#        [ 1.56538735,  0.05519377, -0.63152046, ..., -0.07051657,
#         -0.93543024, -0.15737726],
#        [ 0.52325339, -0.86281016, -0.82400105, ..., -0.07051657,
#         -0.93543024,  6.35415833],
#        [ 0.64214114, -0.82410046, -0.66231735, ..., -0.07051657,
#          1.0690268 , -0.15737726]])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train_std, X_test_std, y_train, y_test = train_test_split(X_std, y, test_size = 0.3, random_state = 100)

# %%
from sklearn.model_selection import cross_val_score, GridSearchCV

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import cross_val_score, KFold

# %%
rmse_rf = []
num_est = [20, 50, 100, 200, 500]


for i in num_est:
    rf=RandomForestRegressor(n_estimators = i, random_state=1,  min_samples_leaf=2)
    kf = KFold(5, shuffle = True, random_state=1)
    mse = cross_val_score(rf ,X_train_std,y_train, scoring = "neg_mean_squared_error", cv=kf) 
    rmse = np.sqrt(np.absolute(mse))
    avg_rmse = np.sum(rmse)/len(rmse)
    rmse_rf.append(avg_rmse)
print(rmse_rf)
# Out:
# [0.4058006189618288, 0.4011086753261348, 0.39959684112769334, 0.3991786063221208, 0.3985338767404262]

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
from sklearn.metrics import r2_score
rf = RandomForestRegressor(n_estimators=500, n_jobs=-1, random_state=1, min_samples_leaf=4, max_depth=15)
RF=rf.fit(X_train_std, y_train)
mse = mean_squared_error(y_test, RF.predict(X_test_std))
print("\n The mean squared error (MSE) on test set: {:.4f} \n".format(mse))
print("\n R2 score on train: \n",r2_score(y_train, RF.predict(X_train_std)))
print("\n R2 score on test: \n",r2_score(y_test, RF.predict(X_test_std)))
# Out:
#  The mean squared error (MSE) on test set: 0.1619
#
#
#  R2 score on train:
#  0.7714926319942396
#
#  R2 score on test:
#  0.6215106205491425

# %%
predicted_real_price = np.exp(RF.predict(X_test_std))

# %% [markdown]
# Since the log transformed has been used for the price for modelling, exponential transformation has been used to get the real predicted price.
